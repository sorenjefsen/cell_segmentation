# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import os
import sys
import cv2

sys.path.append(r"C:\Users\sjefs\Desktop\Uni\Speciale\Kode\library")
import CV_functions as CV_func
import CV_classes as CV_class
from PIL import Image
from PIL.TiffTags import TAGS
import matplotlib.pyplot as plt
import random

# %% [markdown]
# # Picture class

# %% [markdown]
# ## Build in functions

# %%
# Loading Image and running some preprocessing

Image = CV_func.load_image("timelapze_z", number = 10, channel = 1)
Image.blur(ksize = (5, 5), sigma = 1.4)
Image.gray()
Image.normalize()
#Image.contrast(clip_limit=1.0, tile_grid_size=(8,8))
Image.display(name = "Processed Image", show_axis = True, show_data = True)
average = Image.average()

plt.figure()
Image.histogram()
plt.show()
